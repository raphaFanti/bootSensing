# %% [markdown]
# # File reader skiboot testing machine

# %% [markdown]
# Experiments at Montebelluna 08.01.2021: Cyclic loading of TLT Speedfit DX and SX with maximal angular displacement as input, starting at an absolut neutral angle of 15°
# Frequency: f=0.7 Hz
# ambient = 20°C
# cold = -20°C
# Session 1: max. 20,5°
# Session 2: max. 22,5°
# Session 3: max. 25,5°
# Session 4: max. 30,5°

# %%
from pandas import DataFrame, read_csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches # plot legend for multiple signals in one plot
import matplotlib.dates as md
 

# Define file names
DX_ambient_file = r'110939_DXambient.xls'
DX_cold_file = r'144741_DXfreddo.xls'
SX_ambient_file = r'112744_SXambient.xls'
SX_cold_file = r'122259_SXfreddo.xls'

# Load filesheet per session and cycle
# DX ambient (4 sessions - cycle 1)
DX_ambient_s1_c1 = pd.read_excel(DX_ambient_file,"Saves_Session 1_Cycle1")
DX_ambient_s2_c1 = pd.read_excel(DX_ambient_file,"Saves_Session 2_Cycle1")
DX_ambient_s3_c1 = pd.read_excel(DX_ambient_file,"Saves_Session 3_Cycle1")
DX_ambient_s4_c1 = pd.read_excel(DX_ambient_file,"Saves_Session 4_Cycle1")
# DX cold
DX_cold_s1_c1 = pd.read_excel(DX_cold_file,"Saves_Session 1_Cycle1")
DX_cold_s1_c2 = pd.read_excel(DX_cold_file,"Saves_Session 1_Cycle2")
DX_cold_s1_c3 = pd.read_excel(DX_cold_file,"Saves_Session 1_Cycle3")
DX_cold_s1_c4 = pd.read_excel(DX_cold_file,"Saves_Session 1_Cycle4")
DX_cold_s1_c5 = pd.read_excel(DX_cold_file,"Saves_Session 1_Cycle5")
DX_cold_s1_c6 = pd.read_excel(DX_cold_file,"Saves_Session 1_Cycle6")
DX_cold_s1_c7 = pd.read_excel(DX_cold_file,"Saves_Session 1_Cycle7")
DX_cold_s1_c8 = pd.read_excel(DX_cold_file,"Saves_Session 1_Cycle8")
DX_cold_s1_c9 = pd.read_excel(DX_cold_file,"Saves_Session 1_Cycle9")


DX_cold_s2_c1 = pd.read_excel(DX_cold_file,"Saves_Session 2_Cycle1")
DX_cold_s2_c2 = pd.read_excel(DX_cold_file,"Saves_Session 2_Cycle2")
DX_cold_s2_c3 = pd.read_excel(DX_cold_file,"Saves_Session 2_Cycle3")
DX_cold_s2_c4 = pd.read_excel(DX_cold_file,"Saves_Session 2_Cycle4")
DX_cold_s2_c5 = pd.read_excel(DX_cold_file,"Saves_Session 2_Cycle5")
DX_cold_s2_c6 = pd.read_excel(DX_cold_file,"Saves_Session 2_Cycle6")
DX_cold_s2_c7 = pd.read_excel(DX_cold_file,"Saves_Session 2_Cycle7")
DX_cold_s2_c8 = pd.read_excel(DX_cold_file,"Saves_Session 2_Cycle8")
DX_cold_s2_c9 = pd.read_excel(DX_cold_file,"Saves_Session 2_Cycle9")

DX_cold_s3_c1 = pd.read_excel(DX_cold_file,"Saves_Session 3_Cycle1")
DX_cold_s3_c2 = pd.read_excel(DX_cold_file,"Saves_Session 3_Cycle2")
DX_cold_s3_c3 = pd.read_excel(DX_cold_file,"Saves_Session 3_Cycle3")
DX_cold_s3_c4 = pd.read_excel(DX_cold_file,"Saves_Session 3_Cycle4")
DX_cold_s3_c5 = pd.read_excel(DX_cold_file,"Saves_Session 3_Cycle5")
DX_cold_s3_c6 = pd.read_excel(DX_cold_file,"Saves_Session 3_Cycle6")
DX_cold_s3_c7 = pd.read_excel(DX_cold_file,"Saves_Session 3_Cycle7")
DX_cold_s3_c8 = pd.read_excel(DX_cold_file,"Saves_Session 3_Cycle8")
DX_cold_s3_c9 = pd.read_excel(DX_cold_file,"Saves_Session 3_Cycle9")

DX_cold_s4_c1 = pd.read_excel(DX_cold_file,"Saves_Session 4_Cycle1")
DX_cold_s4_c2 = pd.read_excel(DX_cold_file,"Saves_Session 4_Cycle2")
DX_cold_s4_c3 = pd.read_excel(DX_cold_file,"Saves_Session 4_Cycle3")
DX_cold_s4_c4 = pd.read_excel(DX_cold_file,"Saves_Session 4_Cycle4")
DX_cold_s4_c5 = pd.read_excel(DX_cold_file,"Saves_Session 4_Cycle5")
DX_cold_s4_c6 = pd.read_excel(DX_cold_file,"Saves_Session 4_Cycle6")
DX_cold_s4_c7 = pd.read_excel(DX_cold_file,"Saves_Session 4_Cycle7")
DX_cold_s4_c8 = pd.read_excel(DX_cold_file,"Saves_Session 4_Cycle8")
DX_cold_s4_c9 = pd.read_excel(DX_cold_file,"Saves_Session 4_Cycle9")

#SX ambient
SX_ambient_s1_c1 = pd.read_excel(SX_ambient_file,"Saves_Session 1_Cycle1")
SX_ambient_s1_c2 = pd.read_excel(SX_ambient_file,"Saves_Session 1_Cycle2")
SX_ambient_s1_c3 = pd.read_excel(SX_ambient_file,"Saves_Session 1_Cycle3")
SX_ambient_s1_c4 = pd.read_excel(SX_ambient_file,"Saves_Session 1_Cycle4")
SX_ambient_s1_c5 = pd.read_excel(SX_ambient_file,"Saves_Session 1_Cycle5")
SX_ambient_s1_c6 = pd.read_excel(SX_ambient_file,"Saves_Session 1_Cycle6")
SX_ambient_s1_c7 = pd.read_excel(SX_ambient_file,"Saves_Session 1_Cycle7")
SX_ambient_s1_c8 = pd.read_excel(SX_ambient_file,"Saves_Session 1_Cycle8")
SX_ambient_s1_c9 = pd.read_excel(SX_ambient_file,"Saves_Session 1_Cycle9")

SX_ambient_s2_c1 = pd.read_excel(SX_ambient_file,"Saves_Session 2_Cycle1")
SX_ambient_s2_c2 = pd.read_excel(SX_ambient_file,"Saves_Session 2_Cycle2")
SX_ambient_s2_c3 = pd.read_excel(SX_ambient_file,"Saves_Session 2_Cycle3")
SX_ambient_s2_c4 = pd.read_excel(SX_ambient_file,"Saves_Session 2_Cycle4")
SX_ambient_s2_c5 = pd.read_excel(SX_ambient_file,"Saves_Session 2_Cycle5")
SX_ambient_s2_c6 = pd.read_excel(SX_ambient_file,"Saves_Session 2_Cycle6")
SX_ambient_s2_c7 = pd.read_excel(SX_ambient_file,"Saves_Session 2_Cycle7")
SX_ambient_s2_c8 = pd.read_excel(SX_ambient_file,"Saves_Session 2_Cycle8")
SX_ambient_s2_c9 = pd.read_excel(SX_ambient_file,"Saves_Session 2_Cycle9")

SX_ambient_s3_c1 = pd.read_excel(SX_ambient_file,"Saves_Session 3_Cycle1")
SX_ambient_s3_c2 = pd.read_excel(SX_ambient_file,"Saves_Session 3_Cycle2")
SX_ambient_s3_c3 = pd.read_excel(SX_ambient_file,"Saves_Session 3_Cycle3")
SX_ambient_s3_c4 = pd.read_excel(SX_ambient_file,"Saves_Session 3_Cycle4")
SX_ambient_s3_c5 = pd.read_excel(SX_ambient_file,"Saves_Session 3_Cycle5")
SX_ambient_s3_c6 = pd.read_excel(SX_ambient_file,"Saves_Session 3_Cycle6")
SX_ambient_s3_c7 = pd.read_excel(SX_ambient_file,"Saves_Session 3_Cycle7")
SX_ambient_s3_c8 = pd.read_excel(SX_ambient_file,"Saves_Session 3_Cycle8")
SX_ambient_s3_c9 = pd.read_excel(SX_ambient_file,"Saves_Session 3_Cycle9")

SX_ambient_s4_c1 = pd.read_excel(SX_ambient_file,"Saves_Session 4_Cycle1")
SX_ambient_s4_c2 = pd.read_excel(SX_ambient_file,"Saves_Session 4_Cycle2")
SX_ambient_s4_c3 = pd.read_excel(SX_ambient_file,"Saves_Session 4_Cycle3")
SX_ambient_s4_c4 = pd.read_excel(SX_ambient_file,"Saves_Session 4_Cycle4")
SX_ambient_s4_c5 = pd.read_excel(SX_ambient_file,"Saves_Session 4_Cycle5")
SX_ambient_s4_c6 = pd.read_excel(SX_ambient_file,"Saves_Session 4_Cycle6")
SX_ambient_s4_c7 = pd.read_excel(SX_ambient_file,"Saves_Session 4_Cycle7")
SX_ambient_s4_c8 = pd.read_excel(SX_ambient_file,"Saves_Session 4_Cycle8")
SX_ambient_s4_c9 = pd.read_excel(SX_ambient_file,"Saves_Session 4_Cycle9")

#SX cold
SX_cold_s1_c1 = pd.read_excel(SX_cold_file,"Saves_Session 1_Cycle1")
SX_cold_s1_c2 = pd.read_excel(SX_cold_file,"Saves_Session 1_Cycle2")
SX_cold_s1_c3 = pd.read_excel(SX_cold_file,"Saves_Session 1_Cycle3")
SX_cold_s1_c4 = pd.read_excel(SX_cold_file,"Saves_Session 1_Cycle4")
SX_cold_s1_c5 = pd.read_excel(SX_cold_file,"Saves_Session 1_Cycle5")
SX_cold_s1_c6 = pd.read_excel(SX_cold_file,"Saves_Session 1_Cycle6")
SX_cold_s1_c7 = pd.read_excel(SX_cold_file,"Saves_Session 1_Cycle7")
SX_cold_s1_c8 = pd.read_excel(SX_cold_file,"Saves_Session 1_Cycle8")
SX_cold_s1_c9 = pd.read_excel(SX_cold_file,"Saves_Session 1_Cycle9")

SX_cold_s2_c1 = pd.read_excel(SX_cold_file,"Saves_Session 2_Cycle1")
SX_cold_s2_c2 = pd.read_excel(SX_cold_file,"Saves_Session 2_Cycle2")
SX_cold_s2_c3 = pd.read_excel(SX_cold_file,"Saves_Session 2_Cycle3")
SX_cold_s2_c4 = pd.read_excel(SX_cold_file,"Saves_Session 2_Cycle4")
SX_cold_s2_c5 = pd.read_excel(SX_cold_file,"Saves_Session 2_Cycle5")
SX_cold_s2_c6 = pd.read_excel(SX_cold_file,"Saves_Session 2_Cycle6")
SX_cold_s2_c7 = pd.read_excel(SX_cold_file,"Saves_Session 2_Cycle7")
SX_cold_s2_c8 = pd.read_excel(SX_cold_file,"Saves_Session 2_Cycle8")
SX_cold_s2_c9 = pd.read_excel(SX_cold_file,"Saves_Session 2_Cycle9")

SX_cold_s3_c1 = pd.read_excel(SX_cold_file,"Saves_Session 3_Cycle1")
SX_cold_s3_c2 = pd.read_excel(SX_cold_file,"Saves_Session 3_Cycle2")
SX_cold_s3_c3 = pd.read_excel(SX_cold_file,"Saves_Session 3_Cycle3")
SX_cold_s3_c4 = pd.read_excel(SX_cold_file,"Saves_Session 3_Cycle4")
SX_cold_s3_c5 = pd.read_excel(SX_cold_file,"Saves_Session 3_Cycle5")
SX_cold_s3_c6 = pd.read_excel(SX_cold_file,"Saves_Session 3_Cycle6")
SX_cold_s3_c7 = pd.read_excel(SX_cold_file,"Saves_Session 3_Cycle7")
SX_cold_s3_c8 = pd.read_excel(SX_cold_file,"Saves_Session 3_Cycle8")
SX_cold_s3_c9 = pd.read_excel(SX_cold_file,"Saves_Session 3_Cycle9")

SX_cold_s4_c1 = pd.read_excel(SX_cold_file,"Saves_Session 4_Cycle1")
SX_cold_s4_c2 = pd.read_excel(SX_cold_file,"Saves_Session 4_Cycle2")
SX_cold_s4_c3 = pd.read_excel(SX_cold_file,"Saves_Session 4_Cycle3")
SX_cold_s4_c4 = pd.read_excel(SX_cold_file,"Saves_Session 4_Cycle4")
SX_cold_s4_c5 = pd.read_excel(SX_cold_file,"Saves_Session 4_Cycle5")
SX_cold_s4_c6 = pd.read_excel(SX_cold_file,"Saves_Session 4_Cycle6")
SX_cold_s4_c7 = pd.read_excel(SX_cold_file,"Saves_Session 4_Cycle7")
SX_cold_s4_c8 = pd.read_excel(SX_cold_file,"Saves_Session 4_Cycle8")
SX_cold_s4_c9 = pd.read_excel(SX_cold_file,"Saves_Session 4_Cycle9")

# %%
DX_cold_s1 = pd.concat([DX_cold_s1_c1,DX_cold_s1_c2,DX_cold_s1_c3,DX_cold_s1_c4,DX_cold_s1_c5,DX_cold_s1_c6,DX_cold_s1_c7,DX_cold_s1_c8,DX_cold_s1_c1,DX_cold_s1_c9],axis=0)
DX_cold_s2 = pd.concat([DX_cold_s2_c1,DX_cold_s2_c2,DX_cold_s2_c3,DX_cold_s2_c4,DX_cold_s2_c5,DX_cold_s2_c6,DX_cold_s2_c7,DX_cold_s2_c8,DX_cold_s2_c1,DX_cold_s2_c9],axis=0)
DX_cold_s3 = pd.concat([DX_cold_s3_c1,DX_cold_s3_c2,DX_cold_s3_c3,DX_cold_s3_c4,DX_cold_s3_c5,DX_cold_s3_c6,DX_cold_s3_c7,DX_cold_s3_c8,DX_cold_s3_c1,DX_cold_s3_c9],axis=0)
DX_cold_s4 = pd.concat([DX_cold_s4_c1,DX_cold_s4_c2,DX_cold_s4_c3,DX_cold_s4_c4,DX_cold_s4_c5,DX_cold_s4_c6,DX_cold_s4_c7,DX_cold_s4_c8,DX_cold_s4_c1,DX_cold_s4_c9],axis=0)

SX_cold_s1 = pd.concat([SX_cold_s1_c1,SX_cold_s1_c2,SX_cold_s1_c3,SX_cold_s1_c4,SX_cold_s1_c5,SX_cold_s1_c6,SX_cold_s1_c7,SX_cold_s1_c8,SX_cold_s1_c1,SX_cold_s1_c9],axis=0)
SX_cold_s2 = pd.concat([SX_cold_s2_c1,SX_cold_s2_c2,SX_cold_s2_c3,SX_cold_s2_c4,SX_cold_s2_c5,SX_cold_s2_c6,SX_cold_s2_c7,SX_cold_s2_c8,SX_cold_s2_c1,SX_cold_s2_c9],axis=0)
SX_cold_s3 = pd.concat([SX_cold_s3_c1,SX_cold_s3_c2,SX_cold_s3_c3,SX_cold_s3_c4,SX_cold_s3_c5,SX_cold_s3_c6,SX_cold_s3_c7,SX_cold_s3_c8,SX_cold_s3_c1,SX_cold_s3_c9],axis=0)
SX_cold_s4 = pd.concat([SX_cold_s4_c1,SX_cold_s4_c2,SX_cold_s4_c3,SX_cold_s4_c4,SX_cold_s4_c5,SX_cold_s4_c6,SX_cold_s4_c7,SX_cold_s4_c8,SX_cold_s4_c1,SX_cold_s4_c9],axis=0)

SX_ambient_s1 = pd.concat([SX_ambient_s1_c1,SX_ambient_s1_c2,SX_ambient_s1_c3,SX_ambient_s1_c4,SX_ambient_s1_c5,SX_ambient_s1_c6,SX_ambient_s1_c7,SX_ambient_s1_c8,SX_ambient_s1_c1,SX_ambient_s1_c9],axis=0)
SX_ambient_s2 = pd.concat([SX_ambient_s2_c1,SX_ambient_s2_c2,SX_ambient_s2_c3,SX_ambient_s2_c4,SX_ambient_s2_c5,SX_ambient_s2_c6,SX_ambient_s2_c7,SX_ambient_s2_c8,SX_ambient_s2_c1,SX_ambient_s2_c9],axis=0)
SX_ambient_s3 = pd.concat([SX_ambient_s3_c1,SX_ambient_s3_c2,SX_ambient_s3_c3,SX_ambient_s3_c4,SX_ambient_s3_c5,SX_ambient_s3_c6,SX_ambient_s3_c7,SX_ambient_s3_c8,SX_ambient_s3_c1,SX_ambient_s3_c9],axis=0)
SX_ambient_s4 = pd.concat([SX_ambient_s4_c1,SX_ambient_s4_c2,SX_ambient_s4_c3,SX_ambient_s4_c4,SX_ambient_s4_c5,SX_ambient_s4_c6,SX_ambient_s4_c7,SX_ambient_s4_c8,SX_ambient_s4_c1,SX_ambient_s4_c9],axis=0)

# %% [markdown]
# # Plot: angular displacement [°] - force [N]

# %%
# DX ambient plot session 1-4 cycle 1
fig1, ax1 = plt.subplots(2, 2, figsize=(13, 11))
ax1[0,0].plot(DX_ambient_s1_c1.iloc[:,3],DX_ambient_s1_c1.iloc[:,2])
ax1[0,0].set(xlabel= 'angle[°]',ylabel='force[N]')
ax1[0,0].set_title('20,5°')
ax1[0,1].plot(DX_ambient_s2_c1.iloc[:,3],DX_ambient_s2_c1.iloc[:,2])
ax1[0,1].set(xlabel= 'angle[°]',ylabel='force[N]')
ax1[0,1].set_title('22,5°')
ax1[1,0].plot(DX_ambient_s3_c1.iloc[:,3],DX_ambient_s3_c1.iloc[:,2])
ax1[1,0].set(xlabel= 'angle[°]',ylabel='force[N]')
ax1[1,0].set_title('25,5°')
ax1[1,1].plot(DX_ambient_s4_c1.iloc[:,3],DX_ambient_s4_c1.iloc[:,2])
ax1[1,1].set(xlabel= 'angle[°]',ylabel='force[N]')
ax1[1,1].set_title('30,5°')
fig1.suptitle('TLT Speedfit DX 20°C',fontsize=16)
fig1.subplots_adjust(top=0.88)
plt.show()

# %%
# DX ambient plot session 1-4 cycle 1
fig2, ax2 = plt.subplots(2, 2, figsize=(13, 11))
ax2[0,0].plot(SX_ambient_s1_c1.iloc[:,3],SX_ambient_s1_c1.iloc[:,2])
ax2[0,0].set(xlabel= 'angle[°]',ylabel='force[N]')
ax2[0,0].set_title('20,5°')
ax2[0,1].plot(SX_ambient_s2_c1.iloc[:,3],SX_ambient_s2_c1.iloc[:,2])
ax2[0,1].set(xlabel= 'angle[°]',ylabel='force[N]')
ax2[0,1].set_title('22,5°')
ax2[1,0].plot(SX_ambient_s3_c1.iloc[:,3],SX_ambient_s3_c1.iloc[:,2])
ax2[1,0].set(xlabel= 'angle[°]',ylabel='force[N]')
ax2[1,0].set_title('25,5°')
ax2[1,1].plot(SX_ambient_s4_c1.iloc[:,3],SX_ambient_s4_c1.iloc[:,2])
ax2[1,1].set(xlabel= 'angle[°]',ylabel='force[N]')
ax2[1,1].set_title('30,5°')
fig2.suptitle('TLT Speedfit SX 20°C',fontsize=16)
fig2.subplots_adjust(top=0.88)
plt.show()

# %%
# DX cold plot session 1-4 cycle 1
fig3, ax3 = plt.subplots(2, 2, figsize=(13, 11))
ax3[0,0].plot(DX_cold_s1_c1.iloc[:,3],DX_cold_s1_c1.iloc[:,2])
ax3[0,0].set(xlabel= 'angle[°]',ylabel='force[N]')
ax3[0,0].set_title('20,5°')
ax3[0,1].plot(DX_cold_s2_c1.iloc[:,3],DX_cold_s2_c1.iloc[:,2])
ax3[0,1].set(xlabel= 'angle[°]',ylabel='force[N]')
ax3[0,1].set_title('22,5°')
ax3[1,0].plot(DX_cold_s3_c1.iloc[:,3],DX_cold_s3_c1.iloc[:,2])
ax3[1,0].set(xlabel= 'angle[°]',ylabel='force[N]')
ax3[1,0].set_title('25,5°')
ax3[1,1].plot(DX_cold_s4_c1.iloc[:,3],DX_cold_s4_c1.iloc[:,2])
ax3[1,1].set(xlabel= 'angle[°]',ylabel='force[N]')
ax3[1,1].set_title('30,5°')
fig3.suptitle('TLT Speedfit DX -20°C',fontsize=16)
fig3.subplots_adjust(top=0.88)
plt.show()

# %%
# SX cold plot session 1-4 cycle 1
fig4, ax4 = plt.subplots(2, 2, figsize=(13, 11))
ax4[0,0].plot(SX_cold_s1_c1.iloc[:,3],SX_cold_s1_c1.iloc[:,2])
ax4[0,0].set(xlabel= 'angle[°]',ylabel='force[N]')
ax4[0,0].set_title('20,5°')
ax4[0,1].plot(SX_cold_s2_c1.iloc[:,3],SX_cold_s2_c1.iloc[:,2])
ax4[0,1].set(xlabel= 'angle[°]',ylabel='force[N]')
ax4[0,1].set_title('22,5°')
ax4[1,0].plot(SX_cold_s3_c1.iloc[:,3],SX_cold_s3_c1.iloc[:,2])
ax4[1,0].set(xlabel= 'angle[°]',ylabel='force[N]')
ax4[1,0].set_title('25,5°')
ax4[1,1].plot(SX_cold_s4_c1.iloc[:,3],SX_cold_s4_c1.iloc[:,2])
ax4[1,1].set(xlabel= 'angle[°]',ylabel='force[N]')
ax4[1,1].set_title('30,5°')
fig4.suptitle('TLT Speedfit SX -20°C',fontsize=16)
fig4.subplots_adjust(top=0.88)
plt.show()

# %%
# Comparison DX and SX 20°C
fig5, ax5 = plt.subplots(2, 2, figsize=(13, 11))
ax5[0,0].plot(SX_ambient_s1_c1.iloc[:,3],SX_ambient_s1_c1.iloc[:,2],'b',DX_ambient_s1_c1.iloc[:,3],DX_ambient_s1_c1.iloc[:,2],'r')
ax5[0,0].set(xlabel= 'angle[°]',ylabel='force[N]')
ax5[0,0].set_title('20,5°')
ax5[0,1].plot(SX_ambient_s2_c1.iloc[:,3],SX_ambient_s2_c1.iloc[:,2],'b', DX_ambient_s2_c1.iloc[:,3],DX_ambient_s2_c1.iloc[:,2],'r')
ax5[0,1].set(xlabel= 'angle[°]',ylabel='force[N]')
ax5[0,1].set_title('22,5°')
ax5[1,0].plot(SX_ambient_s3_c1.iloc[:,3],SX_ambient_s3_c1.iloc[:,2],'b', DX_ambient_s3_c1.iloc[:,3],DX_ambient_s3_c1.iloc[:,2],'r')
ax5[1,0].set(xlabel= 'angle[°]',ylabel='force[N]')
ax5[1,0].set_title('25,5°')
ax5[1,1].plot(SX_ambient_s4_c1.iloc[:,3],SX_ambient_s4_c1.iloc[:,2],'b', DX_ambient_s4_c1.iloc[:,3],DX_ambient_s4_c1.iloc[:,2],'r')
ax5[1,1].set(xlabel= 'angle[°]',ylabel='force[N]')
ax5[1,1].set_title('30,5°')
fig5.suptitle('DX and SX 20°C',fontsize=16)
fig5.subplots_adjust(top=0.88)
blue_patch = mpatches.Patch(color='blue', label='SX')
red_patch = mpatches.Patch(color='red', label='DX')
plt.legend(handles=[blue_patch,red_patch])
plt.locator_params(axis='x', nbins=10)
plt.show()

# %%
# Comparison DX and SX -20°C
fig6, ax6 = plt.subplots(2, 2, figsize=(13, 11))
ax6[0,0].plot(SX_cold_s1_c1.iloc[:,3],SX_cold_s1_c1.iloc[:,2],'b',DX_cold_s1_c1.iloc[:,3],DX_cold_s1_c1.iloc[:,2],'r')
ax6[0,0].set(xlabel= 'angle[°]',ylabel='force[N]')
ax6[0,0].set_title('20,5°')
ax6[0,1].plot(SX_cold_s2_c1.iloc[:,3],SX_cold_s2_c1.iloc[:,2],'b',DX_cold_s2_c1.iloc[:,3],DX_cold_s2_c1.iloc[:,2],'r')
ax6[0,1].set(xlabel= 'angle[°]',ylabel='force[N]')
ax6[0,1].set_title('22,5°')
ax6[1,0].plot(SX_cold_s3_c1.iloc[:,3],SX_cold_s3_c1.iloc[:,2],'b',DX_cold_s3_c1.iloc[:,3],DX_cold_s3_c1.iloc[:,2],'r')
ax6[1,0].set(xlabel= 'angle[°]',ylabel='force[N]')
ax6[1,0].set_title('25,5°')
ax6[1,1].plot(SX_cold_s4_c1.iloc[:,3],SX_cold_s4_c1.iloc[:,2],'b',DX_cold_s4_c1.iloc[:,3],DX_cold_s4_c1.iloc[:,2],'r')
ax6[1,1].set(xlabel= 'angle[°]',ylabel='force[N]')
ax6[1,1].set_title('30,5°')
fig6.suptitle('DX and SX -20°C',fontsize=16)
blue_patch = mpatches.Patch(color='blue', label='SX')
red_patch = mpatches.Patch(color='red', label='DX')
plt.legend(handles=[blue_patch,red_patch])
plt.locator_params(axis='x', nbins=10)
fig6.subplots_adjust(top=0.88)
plt.show()

# %%
# angle 3, force 2
# std_dev(force/angle)
s_nr = [1,2,3,4]

# DX cold
std_devDX_cold_s1 = np.std(DX_cold_s1.iloc[:,2]/DX_cold_s1.iloc[:,3])
std_devDX_cold_s2 = np.std(DX_cold_s2.iloc[:,2]/DX_cold_s2.iloc[:,3])
std_devDX_cold_s3 = np.std(DX_cold_s3.iloc[:,2]/DX_cold_s3.iloc[:,3])
std_devDX_cold_s4 = np.std(DX_cold_s4.iloc[:,2]/DX_cold_s4.iloc[:,3])
std_devDX_cold = [std_devDX_cold_s1,std_devDX_cold_s2,std_devDX_cold_s3,std_devDX_cold_s4]
#SX cold
std_devSX_cold_s1 = np.std(SX_cold_s1.iloc[:,2]/SX_cold_s1.iloc[:,3])
std_devSX_cold_s2 = np.std(SX_cold_s2.iloc[:,2]/SX_cold_s2.iloc[:,3])
std_devSX_cold_s3 = np.std(SX_cold_s3.iloc[:,2]/SX_cold_s3.iloc[:,3])
std_devSX_cold_s4 = np.std(SX_cold_s4.iloc[:,2]/SX_cold_s4.iloc[:,3])
std_devSX_cold = [std_devSX_cold_s1,std_devSX_cold_s2,std_devSX_cold_s3,std_devSX_cold_s4]

#DXambient
std_devDX_ambient = np.std(DX_ambient_s1)
std_devDX_ambient = np.std(DX_ambient_s2)
std_devDX_ambient = np.std(DX_ambient_s3)
std_devDX_ambient = np.std(DX_ambient_s4)


#SX ambient
std_devSX_ambient_s1 = np.std(SX_ambient_s1.iloc[:,2]/SX_ambient_s1.iloc[:,3])
std_devSX_ambient_s2 = np.std(SX_ambient_s2.iloc[:,2]/SX_ambient_s2.iloc[:,3])
std_devSX_ambient_s3 = np.std(SX_ambient_s3.iloc[:,2]/SX_ambient_s3.iloc[:,3])
std_devSX_ambient_s4 = np.std(SX_ambient_s4.iloc[:,2]/SX_ambient_s4.iloc[:,3])
std_devSX_ambient = [std_devSX_ambient_s1,std_devSX_ambient_s2,std_devSX_ambient_s3,std_devSX_ambient_s4]

plt.plot(s_nr,std_devDX_cold,'ro',s_nr, std_devSX_cold,'bo',s_nr,std_devSX_ambient,'go')
plt.title('Std Dev DX-SX cold')
plt.legend(['DXcold', 'SXcold','SXambient'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-6e209ee23cd0> in <module>
#      17
#      18 #DXambient
# ---> 19 std_devDX_ambient = np.std(DX_ambient_s1)
#      20 std_devDX_ambient = np.std(DX_ambient_s2)
#      21 std_devDX_ambient = np.std(DX_ambient_s3)
#
# NameError: name 'DX_ambient_s1' is not defined
